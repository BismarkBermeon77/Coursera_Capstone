# %% [markdown]
# ## Trabajo Final Semana 1 DATOS

# %%
import requests # librería para manejar las solicitudes
import pandas as pd # librería para análisis de datos
import numpy as np # librería para manejar datos vectorizados
import random # librería para generar números aleatorios

# !pip install geopy
from geopy.geocoders import Nominatim # módulo para convertir una dirección en valores de latitud y longitud 

# librerías para mostrar imágenes 
from IPython.display import Image 
from IPython.core.display import HTML 
    
# librería para convertir un archivo json en un dataframe pandas
from pandas.io.json import json_normalize

#! pip install folium==0.5.0
##! pip install geocoder

import folium # librería para graficar 

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in c:\users\user\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\user\anaconda3\lib\site-packages (from geopy) (2.0)
# Folium installed
# Libraries imported.
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#cargar archivo csv con las coordenadas de los campus de New Bronswick Colleges
coordenadas = pd.read_csv('TrabajoFinalCapstoneCoordenadasNBCC.csv')
coordenadas.head()
# Out:
#                       Campus    Latitud   Longitud
# 0           NBCC Fredericton  45.947068 -66.644382
# 1               NBCC Moncton  46.108091 -64.829347
# 2             NBCC Miramichi  47.028173 -65.466482
# 3            NBCC St Andrews  45.077800 -67.054616
# 4  NBCC Saint John Grandview  45.286812 -65.993679

# %%
#Como datos referenciales tomaremos inicialmente la ubicacion de la capital'
address = 'Fredericton'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 45.94845575 -66.6530224218406

# %%
#obtener un ejemplo de los lugares cercanos al centro de la ciudad desde la API de Foursquare
import pprint
import json, requests

V = '20230424'
LIMIT = 50
radius = 500

url = 'https://api.foursquare.com/v3/places/search?&ll={},{}&radius={}&limit={}'.format(
            latitude, 
            longitude, 
            radius, 
            LIMIT
            )

headers = {
        'Accept': 'application/json',
        'Authorization': 'fsq3I4dlwnIeFKS3V4g2uVHafKaUXeVU+9ESR6JECITFFAE='
    }

data = requests.request("GET",url, headers=headers)
data_dict = json.loads(data.text)
data_dict
# Out:
# {'results': [{'fsq_id': 'b2af55aa895745fb2ff5d76c',
#    'categories': [{'id': 11083,
#      'name': 'Electrician',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 71,
#    'geocodes': {'main': {'latitude': 45.947818, 'longitude': -66.653116},
#     'roof': {'latitude': 45.947818, 'longitude': -66.653116}},
#    'link': '/v3/places/b2af55aa895745fb2ff5d76c',
#    'location': {'address': '538 Squires St',
#     'country': 'CA',
#     'formatted_address': '538 Squires St, Fredericton NB E3B 3V4',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 3V4',
#     'region': 'NB'},
#    'name': 'TW Electric',
#    'related_places': {}},
#   {'fsq_id': '94e2316090684126aee1ba2c',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 168,
#    'geocodes': {'main': {'latitude': 45.949963, 'longitude': -66.652752},
#     'roof': {'latitude': 45.949963, 'longitude': -66.652752}},
#    'link': '/v3/places/94e2316090684126aee1ba2c',
#    'location': {'address': '440 King St',
#     'country': 'CA',
#     'formatted_address': '440 King St, Fredericton NB E3B 5H8',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 5H8',
#     'region': 'NB'},
#    'name': 'Noralyns Bakery',
#    'related_places': {}},
#   {'fsq_id': 'ef34f6e5b7a241df9e4091fb',
#    'categories': [{'id': 11163,
#      'name': 'Shipping, Freight, and Material Transportation Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 168,
#    'geocodes': {'main': {'latitude': 45.949963, 'longitude': -66.652752},
#     'roof': {'latitude': 45.949963, 'longitude': -66.652752}},
#    'link': '/v3/places/ef34f6e5b7a241df9e4091fb',
#    'location': {'address': '440 King St',
#     'country': 'CA',
#     'formatted_address': '440 King St, Fredericton NB E3B 5H8',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 5H8',
#     'region': 'NB'},
#    'name': 'Purolator',
#    'related_places': {}},
#   {'fsq_id': '44dd4dc8c1d64cbc14f88575',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 176,
#    'geocodes': {'main': {'latitude': 45.950037, 'longitude': -66.65318},
#     'roof': {'latitude': 45.950037, 'longitude': -66.65318}},
#    'link': '/v3/places/44dd4dc8c1d64cbc14f88575',
#    'location': {'address': '440 King St',
#     'country': 'CA',
#     'formatted_address': '440 King St, Fredericton NB E3B 5H8',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 5H8',
#     'region': 'NB'},
#    'name': "Crabby Jack's Seafood",
#    'related_places': {}},
#   {'fsq_id': 'e98467e800694fb8d1102d32',
#    'categories': [{'id': 11079,
#      'name': 'Carpet and Flooring Contractor',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 233,
#    'geocodes': {'drop_off': {'latitude': 45.946633, 'longitude': -66.651205},
#     'main': {'latitude': 45.946723, 'longitude': -66.65131},
#     'roof': {'latitude': 45.946723, 'longitude': -66.65131}},
#    'link': '/v3/places/e98467e800694fb8d1102d32',
#    'location': {'address': '830 Regent St',
#     'country': 'CA',
#     'formatted_address': '830 Regent St, Fredericton NB E3B 3Y4',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 3Y4',
#     'region': 'NB'},
#    'name': "McElman's Flooring",
#    'related_places': {}},
#   {'fsq_id': '9a682d8d339c4fa34564b08a',
#    'categories': [{'id': 11043,
#      'name': 'Accounting and Bookkeeping Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 242,
#    'geocodes': {'main': {'latitude': 45.949129, 'longitude': -66.65601},
#     'roof': {'latitude': 45.949129, 'longitude': -66.65601}},
#    'link': '/v3/places/9a682d8d339c4fa34564b08a',
#    'location': {'address': '373 Oxford St',
#     'country': 'CA',
#     'formatted_address': '373 Oxford St, Fredericton NB E3B 2W6',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 2W6',
#     'region': 'NB'},
#    'name': 'T S Enterprises Ltd',
#    'related_places': {}},
#   {'fsq_id': '4c5388b0f5f3d13ac74ba5f8',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 475,
#    'geocodes': {'drop_off': {'latitude': 45.950835, 'longitude': -66.647625},
#     'main': {'latitude': 45.951074, 'longitude': -66.647906},
#     'roof': {'latitude': 45.951074, 'longitude': -66.647906}},
#    'link': '/v3/places/4c5388b0f5f3d13ac74ba5f8',
#    'location': {'address': 'Regent St',
#     'country': 'CA',
#     'cross_street': 'Scully St',
#     'formatted_address': 'Regent St (Scully St), Fredericton NB',
#     'locality': 'Fredericton',
#     'region': 'NB'},
#    'name': '20 Twenty Club',
#    'related_places': {},
#    'timezone': 'America/Moncton'},
#   {'fsq_id': '1e320003b653467628e17324',
#    'categories': [{'id': 11163,
#      'name': 'Shipping, Freight, and Material Transportation Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 301,
#    'geocodes': {'main': {'latitude': 45.94978, 'longitude': -66.64962},
#     'roof': {'latitude': 45.94978, 'longitude': -66.64962}},
#    'link': '/v3/places/1e320003b653467628e17324',
#    'location': {'address': '621 Regent St',
#     'country': 'CA',
#     'formatted_address': '621 Regent St, Fredericton NB E3B 3Y2',
#     'locality': 'Fredericton',
#     'po_box': 'PO Box 1023',
#     'postcode': 'E3B 3Y2',
#     'region': 'NB'},
#    'name': 'Beaver Brokerage Inc',
#    'related_places': {}},
#   {'fsq_id': 'cc723042768b42ff0225b0f3',
#    'categories': [{'id': 11170,
#      'name': 'Telecommunication Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 320,
#    'geocodes': {'main': {'latitude': 45.950112, 'longitude': -66.656422},
#     'roof': {'latitude': 45.950112, 'longitude': -66.656422}},
#    'link': '/v3/places/cc723042768b42ff0225b0f3',
#    'location': {'address': '79 Pembroke Cres',
#     'country': 'CA',
#     'formatted_address': '79 Pembroke Cres, Fredericton NB E3B 2V1',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 2V1',
#     'region': 'NB'},
#    'name': 'Friedman Stanton T',
#    'related_places': {}},
#   {'fsq_id': '440f084ea9264224fcd56722',
#    'categories': [{'id': 17091,
#      'name': 'Hobby Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hobbyshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 341,
#    'geocodes': {'main': {'latitude': 45.951437, 'longitude': -66.654073},
#     'roof': {'latitude': 45.951437, 'longitude': -66.654073}},
#    'link': '/v3/places/440f084ea9264224fcd56722',
#    'location': {'address': '358 Edinburgh St',
#     'country': 'CA',
#     'formatted_address': '358 Edinburgh St, Fredericton NB E3B 2C9',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 2C9',
#     'region': 'NB'},
#    'name': 'Duguay Billiards & Games',
#    'related_places': {}},
#   {'fsq_id': '140c33d0ac9f4cb57d5b194d',
#    'categories': [{'id': 11169,
#      'name': 'Website Designer',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 341,
#    'geocodes': {'drop_off': {'latitude': 45.951494, 'longitude': -66.651651},
#     'main': {'latitude': 45.951332, 'longitude': -66.651466},
#     'roof': {'latitude': 45.951332, 'longitude': -66.651466}},
#    'link': '/v3/places/140c33d0ac9f4cb57d5b194d',
#    'location': {'address': '664 Mitchell St',
#     'country': 'CA',
#     'formatted_address': '664 Mitchell St, Fredericton NB E3B 3S6',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 3S6',
#     'region': 'NB'},
#    'name': 'Gray Perspective',
#    'related_places': {}},
#   {'fsq_id': '4b7acb0ef964a520113d2fe3',
#    'categories': [{'id': 16032,
#      'name': 'Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#       'suffix': '.png'}},
#     {'id': 16037,
#      'name': 'Playground',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 462,
#    'geocodes': {'main': {'latitude': 45.950973, 'longitude': -66.64821},
#     'roof': {'latitude': 45.950973, 'longitude': -66.64821}},
#    'link': '/v3/places/4b7acb0ef964a520113d2fe3',
#    'location': {'address': 'Aberdeen St',
#     'country': 'CA',
#     'formatted_address': 'Aberdeen St, Fredericton NB',
#     'locality': 'Fredericton',
#     'region': 'NB'},
#    'name': 'Queen Square Tennis Courts',
#    'related_places': {},
#    'timezone': 'America/Moncton'},
#   {'fsq_id': '501cb2a0e4b0f873f7c594d6',
#    'categories': [{'id': 13011,
#      'name': 'Gay Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 462,
#    'geocodes': {'main': {'latitude': 45.950864, 'longitude': -66.64832},
#     'roof': {'latitude': 45.950864, 'longitude': -66.64832}},
#    'link': '/v3/places/501cb2a0e4b0f873f7c594d6',
#    'location': {'address': 'Dondonald St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': 'Dondonald St, Fredericton NB',
#     'locality': 'Fredericton',
#     'region': 'NB'},
#    'name': 'Club Score',
#    'related_places': {},
#    'timezone': 'America/Moncton'},
#   {'fsq_id': '49a683d38d574c83382e6814',
#    'categories': [{'id': 11101,
#      'name': 'Tree Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 366,
#    'geocodes': {'drop_off': {'latitude': 45.951538, 'longitude': -66.653862},
#     'main': {'latitude': 45.95171, 'longitude': -66.653797},
#     'roof': {'latitude': 45.95171, 'longitude': -66.653797}},
#    'link': '/v3/places/49a683d38d574c83382e6814',
#    'location': {'address': '379 Edinburgh St',
#     'country': 'CA',
#     'formatted_address': '379 Edinburgh St, Fredericton NB E3B 2E2',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 2E2',
#     'region': 'NB'},
#    'name': 'Wildwood Tree Svc',
#    'related_places': {}},
#   {'fsq_id': 'c1b24b31e8e24bbcfd831ff6',
#    'categories': [],
#    'chains': [],
#    'distance': 366,
#    'geocodes': {'drop_off': {'latitude': 45.946669, 'longitude': -66.648777},
#     'main': {'latitude': 45.946796, 'longitude': -66.648923},
#     'roof': {'latitude': 45.946796, 'longitude': -66.648923}},
#    'link': '/v3/places/c1b24b31e8e24bbcfd831ff6',
#    'location': {'address': '795 Hanson St',
#     'country': 'CA',
#     'formatted_address': '795 Hanson St, Fredericton NB E3B 4A5',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 4A5',
#     'region': 'NB'},
#    'name': 'DiGiacinto Joseph',
#    'related_places': {}},
#   {'fsq_id': '56adf6e2498efe20378cdb82',
#    'categories': [{'id': 11045,
#      'name': 'Bank',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'}},
#     {'id': 11051,
#      'name': 'Credit Union',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 492,
#    'geocodes': {'main': {'latitude': 45.94404, 'longitude': -66.65242},
#     'roof': {'latitude': 45.94404, 'longitude': -66.65242}},
#    'link': '/v3/places/56adf6e2498efe20378cdb82',
#    'location': {'address': '650 Montgomery St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '650 Montgomery St, Fredericton NB E3B 5R6',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 5R6',
#     'region': 'NB'},
#    'name': 'Nbta Credit Union',
#    'related_places': {},
#    'timezone': 'America/Moncton'},
#   {'fsq_id': '04530fe39bb546f5b72ce0df',
#    'categories': [{'id': 12091,
#      'name': 'Public and Social Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 381,
#    'geocodes': {'main': {'latitude': 45.945759, 'longitude': -66.649974},
#     'roof': {'latitude': 45.945759, 'longitude': -66.649974}},
#    'link': '/v3/places/04530fe39bb546f5b72ce0df',
#    'location': {'address': '860 Grandame St',
#     'country': 'CA',
#     'formatted_address': '860 Grandame St, Fredericton NB E3B 3Z8',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 3Z8',
#     'region': 'NB'},
#    'name': 'Fredericton Food Bank',
#    'related_places': {}},
#   {'fsq_id': '74132859902b42e734b5ad0b',
#    'categories': [{'id': 11165,
#      'name': 'Storage Facility',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/storage_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 399,
#    'geocodes': {'main': {'latitude': 45.945674, 'longitude': -66.656294},
#     'roof': {'latitude': 45.945674, 'longitude': -66.656294}},
#    'link': '/v3/places/74132859902b42e734b5ad0b',
#    'location': {'address': 'Lower St',
#     'country': 'CA',
#     'formatted_address': 'Lower St, Fredericton NB E3A 7B1',
#     'locality': 'Fredericton',
#     'postcode': 'E3A 7B1',
#     'region': 'NB'},
#    'name': 'Chain Lake Enterprises',
#    'related_places': {}},
#   {'fsq_id': '10dee0f1b95942cfb64df796',
#    'categories': [{'id': 12082,
#      'name': 'Organization',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 399,
#    'geocodes': {'main': {'latitude': 45.945674, 'longitude': -66.656294},
#     'roof': {'latitude': 45.945674, 'longitude': -66.656294}},
#    'link': '/v3/places/10dee0f1b95942cfb64df796',
#    'location': {'address': '200 Miles St',
#     'country': 'CA',
#     'formatted_address': '200 Miles St, Fredericton NB E3A 3J7',
#     'locality': 'Fredericton',
#     'postcode': 'E3A 3J7',
#     'region': 'NB'},
#    'name': 'Ambulance Saint-Jean-Formation Service et Fournitures de Premiers Soins',
#    'related_places': {}},
#   {'fsq_id': '2926a7a95f1c44e2d754e981',
#    'categories': [{'id': 12082,
#      'name': 'Organization',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 428,
#    'geocodes': {'main': {'latitude': 45.944742, 'longitude': -66.651508},
#     'roof': {'latitude': 45.944742, 'longitude': -66.651508}},
#    'link': '/v3/places/2926a7a95f1c44e2d754e981',
#    'location': {'address': '650 Montgomery St',
#     'country': 'CA',
#     'formatted_address': '650 Montgomery St, Fredericton NB E3B 2X8',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 2X8',
#     'region': 'NB'},
#    'name': 'Federation des enseignants du Nouveau-Brunswick',
#    'related_places': {}},
#   {'fsq_id': '2b8983c0caae413c7edbaed5',
#    'categories': [],
#    'chains': [],
#    'distance': 437,
#    'geocodes': {'drop_off': {'latitude': 45.950839, 'longitude': -66.64853},
#     'main': {'latitude': 45.950755, 'longitude': -66.648431},
#     'roof': {'latitude': 45.950755, 'longitude': -66.648431}},
#    'link': '/v3/places/2b8983c0caae413c7edbaed5',
#    'location': {'address': '646 Chestnut St',
#     'country': 'CA',
#     'formatted_address': '646 Chestnut St, Fredericton NB E3B 3W2',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 3W2',
#     'region': 'NB'},
#    'name': 'Fredericton Wee Piggies and Paws',
#    'related_places': {}},
#   {'fsq_id': '71028a190104422eff8913c1',
#    'categories': [{'id': 11053,
#      'name': 'Financial Planner',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 446,
#    'geocodes': {'main': {'latitude': 45.944527, 'longitude': -66.651826}},
#    'link': '/v3/places/71028a190104422eff8913c1',
#    'location': {'address': '650 Montgomery St',
#     'country': 'CA',
#     'formatted_address': '650 Montgomery St, Fredericton NB E3B 5C8',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 5C8',
#     'region': 'NB'},
#    'name': 'Credential Financial Strategies',
#    'related_places': {}},
#   {'fsq_id': 'f9da631591654981eddcfd39',
#    'categories': [{'id': 11042,
#      'name': 'Financial Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 468,
#    'geocodes': {'drop_off': {'latitude': 45.944334, 'longitude': -66.651024},
#     'main': {'latitude': 45.944492, 'longitude': -66.650957},
#     'roof': {'latitude': 45.944492, 'longitude': -66.650957}},
#    'link': '/v3/places/f9da631591654981eddcfd39',
#    'location': {'address': '650 Montgomery St',
#     'country': 'CA',
#     'formatted_address': '650 Montgomery St, Fredericton NB E3B 2X8',
#     'locality': 'Fredericton',
#     'postcode': 'E3B 2X8',
#     'region': 'NB'},
#    'name': 'HSBC ATM',
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 45.94845575,
#      'longitude': -66.6530224218406},
#     'radius': 500}}}}
